# %%
import math

sig = 	5.670374419e-8
L = 3.84e33
r = 1
k = 1 / (16 * sig * math.pi)
k **(0.25)
# Out:
# 24.33770384210061

# %%
import math

sig = 	5.670374419e-8
L = 3.84e33
T = 170
r = math.sqrt(1/(16*math.pi*sig))

r
# Out:
# 837.6723913068131
